# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %%
# Read in NASDAQ Composite 1995-2005 data from csv file
IXIC_path = Path('^IXIC.csv')
IXIC_df = pd.read_csv(IXIC_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
IXIC_df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1995-01-03   751.309998   751.309998   743.530029   743.580017   743.580017
# 1995-01-04   744.770020   746.419983   740.469971   745.840027   745.840027
# 1995-01-05   746.869995   748.500000   745.130005   745.659973   745.659973
# 1995-01-06   746.270020   750.729980   745.760010   749.690002   749.690002
# 1995-01-09   750.190002   752.840027   750.099976   752.090027   752.090027
# ...                 ...          ...          ...          ...          ...
# 2004-12-28  2156.750000  2177.189941  2156.530029  2177.189941  2177.189941
# 2004-12-29  2170.989990  2182.330078  2170.989990  2177.000000  2177.000000
# 2004-12-30  2177.469971  2182.370117  2176.399902  2178.340088  2178.340088
# 2004-12-31  2178.979980  2185.560059  2174.629883  2175.439941  2175.439941
# 2005-01-03  2184.750000  2191.600098  2148.719971  2152.149902  2152.149902
#
#                 Volume
# Date
# ...

# %%
# Checking for nulls
IXIC_df.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Dropping additional columns
IXIC_df = IXIC_df.drop(columns=['Open', 'High', 'Low', 'Volume', 'Adj Close'])
IXIC_df
# Out:
#                   Close
# Date
# 1995-01-03   743.580017
# 1995-01-04   745.840027
# 1995-01-05   745.659973
# 1995-01-06   749.690002
# 1995-01-09   752.090027
# ...                 ...
# 2004-12-28  2177.189941
# 2004-12-29  2177.000000
# 2004-12-30  2178.340088
# 2004-12-31  2175.439941
# 2005-01-03  2152.149902
#
# [2520 rows x 1 columns]

# %%
IXIC_df.plot(figsize=(20,10), ylabel='IXIC 1995-2005 Closing Price')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='IXIC 1995-2005 Closing Price'>

# %%
# Reading in Nasdaq Composite 2014-2021 data
IXIC_2_path = Path('^IXIC_2.csv')
IXIC_2_df = pd.read_csv(IXIC_2_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
IXIC_2_df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2011-09-15   2595.449951   2608.949951   2569.780029   2607.070068
# 2011-09-16   2607.120117   2627.280029   2600.959961   2622.310059
# 2011-09-19   2584.350098   2627.340088   2564.459961   2612.830078
# 2011-09-20   2623.889893   2643.370117   2589.520020   2590.239990
# 2011-09-21   2601.060059   2613.290039   2537.459961   2538.189941
# ...                  ...           ...           ...           ...
# 2021-09-13  15211.429688  15215.440430  15030.849609  15105.580078
# 2021-09-14  15168.450195  15181.190430  15008.299805  15037.759766
# 2021-09-15  15071.339844  15174.379883  14984.679688  15161.530273
# 2021-09-16  15120.089844  15205.500000  15047.139648  15181.919922
# 2021-09-17  15163.360352  15166.559570  14998.730469  15043.969727
#
#                Adj Close      Volume
# Date
# 2011-09-15   2607.070068  1967730000
# 2011-09-16   2622.310059  2703730000
# ...

# %%
# Checking for nulls
IXIC_2_df.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Dropping additional columns
IXIC_2_df = IXIC_2_df.drop(columns=['Open', 'High', 'Low', 'Volume', 'Adj Close'])
IXIC_2_df
# Out:
#                    Close
# Date
# 2011-09-15   2607.070068
# 2011-09-16   2622.310059
# 2011-09-19   2612.830078
# 2011-09-20   2590.239990
# 2011-09-21   2538.189941
# ...                  ...
# 2021-09-13  15105.580078
# 2021-09-14  15037.759766
# 2021-09-15  15161.530273
# 2021-09-16  15181.919922
# 2021-09-17  15043.969727
#
# [2519 rows x 1 columns]

# %%
IXIC_2_df.plot(figsize=(20,10), ylabel='IXIC 2011-2021 Closing Price')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='IXIC 2011-2021 Closing Price'>

# %%
# Read in BTC 2011-2021 data from csv file
BTC_path = Path('BTC_USD.csv')
BTC_df = pd.read_csv(BTC_path, parse_dates=True, infer_datetime_format=True, index_col='Date')
BTC_df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2021-09-13  46057.214844  46598.679688  43591.320313  44963.074219
# 2021-09-14  44960.050781  47218.125000  44752.332031  47092.492188
# 2021-09-15  47098.000000  48450.468750  46773.328125  48176.347656
# 2021-09-16  48158.906250  48486.828125  47079.558594  47783.359375
# 2021-09-17  47771.003906  48160.921875  46832.523438  47267.519531
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# ...

# %%
# Checking for nulls
BTC_df.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Dropping additional columns
BTC_df = BTC_df.drop(columns=['Open', 'High', 'Low', 'Adj Close', 'Volume'])
BTC_df
# Out:
#                    Close
# Date
# 2014-09-17    457.334015
# 2014-09-18    424.440002
# 2014-09-19    394.795990
# 2014-09-20    408.903992
# 2014-09-21    398.821014
# ...                  ...
# 2021-09-13  44963.074219
# 2021-09-14  47092.492188
# 2021-09-15  48176.347656
# 2021-09-16  47783.359375
# 2021-09-17  47267.519531
#
# [2558 rows x 1 columns]

# %%
BTC_df.plot(figsize=(20,10), ylabel='BTC 2014-2021 Price')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='BTC 2014-2021 Price'>

# %%
# Calculate daily returns for NASDAQ Composite from 1995-2005 and removing null values
IXIC_daily_returns = IXIC_df.pct_change()
IXIC_daily_returns.dropna(inplace=True)
IXIC_daily_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
IXIC_daily_returns
# Out:
#                Close
# Date
# 1995-01-04  0.003039
# 1995-01-05 -0.000241
# 1995-01-06  0.005405
# 1995-01-09  0.003201
# 1995-01-10  0.005890
# ...              ...
# 2004-12-28  0.010663
# 2004-12-29 -0.000087
# 2004-12-30  0.000616
# 2004-12-31 -0.001331
# 2005-01-03 -0.010706
#
# [2519 rows x 1 columns]

# %%
IXIC_daily_returns.columns = ['^IXIC Returns']
IXIC_daily_returns.head()
# Out:
#             ^IXIC Returns
# Date
# 1995-01-04       0.003039
# 1995-01-05      -0.000241
# 1995-01-06       0.005405
# 1995-01-09       0.003201
# 1995-01-10       0.005890

# %%
IXIC_daily_returns.plot(figsize=(20,10), ylabel='^IXIC 1995-2005 Returns')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='^IXIC 1995-2005 Returns'>

# %%
# Calculate daily returns for NASDAQ Composite from 2014-2021 and removing null values
IXIC_2_daily_returns = IXIC_2_df.pct_change()
IXIC_2_daily_returns.dropna(inplace=True)
IXIC_2_daily_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
IXIC_2_daily_returns
# Out:
#                Close
# Date
# 2011-09-16  0.005846
# 2011-09-19 -0.003615
# 2011-09-20 -0.008646
# 2011-09-21 -0.020095
# 2011-09-22 -0.032511
# ...              ...
# 2021-09-13 -0.000656
# 2021-09-14 -0.004490
# 2021-09-15  0.008231
# 2021-09-16  0.001345
# 2021-09-17 -0.009086
#
# [2518 rows x 1 columns]

# %%
IXIC_2_daily_returns.columns = ['^IXIC 2 Returns']
IXIC_2_daily_returns.head()
# Out:
#             ^IXIC 2 Returns
# Date
# 2011-09-16         0.005846
# 2011-09-19        -0.003615
# 2011-09-20        -0.008646
# 2011-09-21        -0.020095
# 2011-09-22        -0.032511

# %%
IXIC_2_daily_returns.plot(figsize=(20,10), ylabel= 'IXIC 2011-2021 Returns')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='IXIC 2011-2021 Returns'>

# %%
# Calculating BTC daily returns and removing null values
BTC_daily_returns = BTC_df.pct_change()
BTC_daily_returns.dropna(inplace=True)
BTC_daily_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
BTC_daily_returns
# Out:
#                Close
# Date
# 2014-09-18 -0.071926
# 2014-09-19 -0.069843
# 2014-09-20  0.035735
# 2014-09-21 -0.024659
# 2014-09-22  0.008352
# ...              ...
# 2021-09-13 -0.023884
# 2021-09-14  0.047359
# 2021-09-15  0.023015
# 2021-09-16 -0.008157
# 2021-09-17 -0.010795
#
# [2557 rows x 1 columns]

# %%
BTC_daily_returns.columns = ['BTC Returns']
BTC_daily_returns.head()
# Out:
#             BTC Returns
# Date
# 2014-09-18    -0.071926
# 2014-09-19    -0.069843
# 2014-09-20     0.035735
# 2014-09-21    -0.024659
# 2014-09-22     0.008352

# %%
BTC_daily_returns.plot(figsize=(20,10), ylabel='BTC 2014-2021 Returns')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='BTC 2014-2021 Returns'>

# %%
# Joining dataframes
joined_returns = pd.concat([BTC_daily_returns, IXIC_daily_returns, IXIC_2_daily_returns])
joined_returns
# Out:
#             BTC Returns  ^IXIC Returns  ^IXIC 2 Returns
# Date
# 2014-09-18    -0.071926            NaN              NaN
# 2014-09-19    -0.069843            NaN              NaN
# 2014-09-20     0.035735            NaN              NaN
# 2014-09-21    -0.024659            NaN              NaN
# 2014-09-22     0.008352            NaN              NaN
# ...                 ...            ...              ...
# 2021-09-13          NaN            NaN        -0.000656
# 2021-09-14          NaN            NaN        -0.004490
# 2021-09-15          NaN            NaN         0.008231
# 2021-09-16          NaN            NaN         0.001345
# 2021-09-17          NaN            NaN        -0.009086
#
# [7594 rows x 3 columns]

# %%
# Plotting returns
joined_returns.plot(figsize=(20,10), ylabel='Returns')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Returns'>

# %%
# IXIC standard deviation
IXIC_std = IXIC_daily_returns.std()
IXIC_std
# Out:
# ^IXIC Returns    0.018297
# dtype: float64

# %%
IXIC_2_std = IXIC_2_daily_returns.std()
IXIC_2_std
# Out:
# ^IXIC 2 Returns    0.011957
# dtype: float64

# %%
# BTC standard deviation
BTC_std = BTC_daily_returns.std()
BTC_std
# Out:
# BTC Returns    0.039112
# dtype: float64

# %%
#Annualized standard deviation
IXIC_annual_std = IXIC_std * np.sqrt(252)
IXIC_2_annual_std = IXIC_2_std * np.sqrt(252)
BTC_annual_std = BTC_std * np.sqrt(252)
print('The annualized standard deviation for the Nasdaq Composite from 1995-2005 is: ' , IXIC_annual_std)
print('The annualized standard deviation for the Nasdaq Composite from 2014-2021 is: ' , IXIC_2_annual_std)
print('The annualized standard deviation for BTC from 2014-2021 is: ', BTC_annual_std)
# Out:
# The annualized standard deviation for the Nasdaq Composite from 1995-2005 is:  ^IXIC Returns    0.290463
# dtype: float64
# The annualized standard deviation for the Nasdaq Composite from 2014-2021 is:  ^IXIC 2 Returns    0.18981
# dtype: float64
# The annualized standard deviation for BTC from 2014-2021 is:  BTC Returns    0.620886
# dtype: float64

# %%
joined_annual_std = pd.concat([IXIC_annual_std, IXIC_2_annual_std, BTC_annual_std])
joined_annual_std.plot(kind='bar',figsize=(20,10), ylabel='Annualized Standard Deviation')
# Out:
# <AxesSubplot:ylabel='Annualized Standard Deviation'>

# %%
sharpe_ratio = ((joined_returns.mean())*252) / (joined_returns.std() * np.sqrt(252))
sharpe_ratio
# Out:
# BTC Returns        1.050375
# ^IXIC Returns      0.511052
# ^IXIC 2 Returns    1.019802
# dtype: float64

# %%
sharpe_ratio.plot(kind='bar', figsize=(20,10), ylabel='Sharpe Ratio', title='Sharpe Ratios of BTC 2014-2021, IXIC 1995-2005, IXIC 2011-2021')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios of BTC 2014-2021, IXIC 1995-2005, IXIC 2011-2021'}, ylabel='Sharpe Ratio'>
